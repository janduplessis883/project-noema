# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/Volumes/JanBackupHD/data-noema/data/noema_classified_topic.csv')

# %%
data.head()

# %%
sns.countplot(data=data, y='topic_label')

# %%
data = pd.read_csv('/Volumes/JanBackupHD/data-noema/data/noema_classified_topic.csv')

# %%
sns.countplot(data=data, y='topic_label')

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/Volumes/JanBackupHD/data-noema/data/training_dataset.csv')
data.head()
# Out:
#                                               review                   class  \
# 0             It is a very efficiently run Practice.  Administrative Process
# 1         Services is quick with clear instructions.  Administrative Process
# 2  Dates I was going to be abroad not correctly r...  Administrative Process
# 3  It’s a brilliant practice Managed well and sta...  Administrative Process
# 4  I had a face to face appt and when she saw me ...  Administrative Process
#
#               segmenter
# 0                 spacy
# 1                 spacy
# 2  sentence_transformer
# 3  sentence_transformer
# 4  sentence_transformer

# %%
sns.countplot(data=data, y='class')
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
sns.countplot(data=data, y='segmenter')
# Out:
# <Axes: xlabel='count', ylabel='segmenter'>

# %% [markdown]
# ### Create **HuggingFace** Dataset file

# %%
data.to_csv('training_dataset.csv', index=False)
